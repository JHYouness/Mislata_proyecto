# %%
from sklearn.linear_model import LinearRegression
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from sklearn.preprocessing import StandardScaler, MinMaxScaler


pd.set_option('display.max_columns', None)

df = pd.read_csv('final_gold.csv')

df['time'] = pd.to_datetime(df['time'])
df['hora'] = df['time'].dt.hour
df['part_of_day'] = df['hora'].apply(lambda h: (
    0 if h < 6 else #Madrugada = 0
    3 if h < 12 else #Mañana = 3
    2 if h < 18 else  #Tarde = 2
    1 #Noche = 1
))

df['mes'] = df['time'].dt.month
df['season'] = df['hora'].apply(lambda h: (
    0 if h in [12,1,2] else #Invierno = 0
    1 if h in [3,4,5] else #Primavera = 1
    2 if h in [6,7,8] else #Verano = 2
    3 #Otoño = 3
))

df['hora_sin'] = np.sin(2 * np.pi * df['hora'] / 23)
df['hora_cos'] = np.cos(2 * np.pi * df['hora'] / 23)

df["dia_semana"] = df["time"].dt.dayofweek  # Día de la semana (0=lunes)
# Codificación one-hot para dia_semana (ahora solo contiene 0 a 4)
df = pd.get_dummies(df, columns=['dia_semana'], prefix='dia', drop_first=True)



X_df = df.drop(columns=["time","temperatura_calefaccion_y",'sensor.sensor_temperatura_2_humidity', 'sensor.sensor_temperatura_2_pressure', 'sensor.sensor_temperatura_2_temperature', 'sensor.sensor_temperatura_3_humidity', 'sensor.sensor_temperatura_3_pressure', 'sensor.sensor_temperatura_3_temperature'])
y_df = df["temperatura_calefaccion_y"]


# probar tasas de aprendizaje, funciones activacion y num neuronas
df.to_csv('entrenamiento_neuronal_calefaccion.csv', index=False)

X_df
# Out:
# R²: 0.9228992506146165
# MAE: 0.5258244571863165
# MSE: 0.43403962779833866
# RMSE: 0.658816839340297
#       sensor.sensor_temperatura_1_humidity  \
# 0                                    46.30
# 1                                    45.78
# 2                                    45.45
# 3                                    45.30
# 4                                    45.25
# ...                                    ...
# 2492                                 47.17
# 2493                                 47.73
# 2494                                 48.80
# 2495                                 49.68
# 2496                                 50.02
#
#       sensor.sensor_temperatura_1_pressure  \
# 0                                   1014.6
# 1                                   1014.6
# 2                                   1014.2
# 3                                   1014.4
# 4                                   1014.4
# ...                                    ...
# 2492                                1011.5
# 2493                                1012.2
# 2494                                1013.2
# 2495                                1013.5
# 2496                                1013.9
#
#       sensor.sensor_temperatura_1_temperature  sensor_puerta_1 Puerta  \
# 0                                       19.74                     0.0
# 1                                       19.51                     0.0
# 2                                       19.24                     0.0
# 3                                       19.09                     0.0
# 4                                       18.86                     0.0
# ...                                       ...                     ...
# 2492                                    21.36                  3600.0
# 2493                                    21.40                  2366.0
# 2494                                    20.71                     0.0
# 2495                                    20.17                     0.0
# 2496                                    19.84                     0.0
#
#       suma_ventanas_arriba  suma_ventanas_abajo  azimuth_mean  elevacion_sol  \
# 0                      0.0                  0.0        285.41         -53.48
# 1                      0.0                  0.0        303.03         -64.02
# 2                      0.0                  0.0        250.84         -72.16
# 3                      0.0                  0.0         29.55         -71.20
# 4                      0.0                  0.0         59.16         -63.06
# ...                    ...                  ...           ...            ...
# 2492                   0.0                  0.0        273.44          -1.18
# 2493                   0.0                  0.0        283.89         -13.52
# 2494                   0.0                  0.0        295.64         -25.12
# 2495                   0.0                  0.0        308.84         -34.89
# 2496                   0.0                  0.0        325.30         -42.77
#
#       temperatura_exterior  porcentaje_nubes  hora  part_of_day  mes  season  \
# 0                     12.5             100.0    21            1   12       3
# 1                     12.0             100.0    22            1   12       3
# 2                     11.4             100.0    23            1   12       3
# 3                     11.2              39.0     0            0   12       3
# 4                     10.6              32.0     1            0   12       0
# ...                    ...               ...   ...          ...  ...     ...
# 2492                  15.5              87.0    18            1    3       3
# 2493                  14.7              56.0    19            1    3       3
# 2494                  13.5              33.0    20            1    3       3
# 2495                  13.1              41.0    21            1    3       3
# 2496                  12.5              54.0    22            1    3       3
#
#           hora_sin  hora_cos  dia_1  dia_2  dia_3  dia_4  dia_5  dia_6
# 0    -5.195840e-01  0.854419   True  False  False  False  False  False
# 1    -2.697968e-01  0.962917   True  False  False  False  False  False
# 2    -2.449294e-16  1.000000   True  False  False  False  False  False
# 3     0.000000e+00  1.000000  False   True  False  False  False  False
# 4     2.697968e-01  0.962917  False   True  False  False  False  False
# ...            ...       ...    ...    ...    ...    ...    ...    ...
# 2492 -9.790841e-01  0.203456  False  False  False  False  False  False
# 2493 -8.878852e-01  0.460065  False  False  False  False  False  False
# 2494 -7.308360e-01  0.682553  False  False  False  False  False  False
# 2495 -5.195840e-01  0.854419  False  False  False  False  False  False
# 2496 -2.697968e-01  0.962917  False  False  False  False  False  False
#
# [2497 rows x 22 columns]
